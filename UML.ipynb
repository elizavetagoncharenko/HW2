# %%
class Driver:
    def __init__(self, driver_id, first_name, last_name, radio_number):
      self.id = driver_id
      self.first_name = first_name
      self.last_name = last_name
      self.radio_number = radio_number

class Vehicle:
    def __init__(self, vehicle_id, x, y, gps_coordinates, driver=None):
      self.x = x
      self.y = y
      self.id = vehicle_id
      self.gps_coordinates = gps_coordinates
      self.driver = driver

    def assign_driver(self, driver):
      self.driver = driver

    def remove_driver(self):
      self.driver = None


class DumpTruck(Vehicle):
    def __init__(self, vehicle_id, x, y, gps_coordinates, driver, load_capacity, model, firm):
      super().__init__(vehicle_id, x, y, gps_coordinates, driver)
      self.load_capacity = load_capacity
      self.model = model
      self.firm = firm

    def load_material(self):
      pass

    def transport(self):
      pass

    def unload_material(self):
      pass


class RegularTruck(Vehicle):
    def __init__(self, vehicle_id, x, y, gps_coordinates, driver, cargo, firm):
      super().__init__(vehicle_id, x, y, gps_coordinates, driver)
      self.cargo = cargo
      self.model = model

    def load_material(self):
      pass

    def transport(self):
      pass

    def unload_material(self):
      pass


class ServiceVehicle(Vehicle):
    def __init__(self, vehicle_id, x, y, gps_coordinates, driver):
      super().__init__(vehicle_id, x, y, gps_coordinates, driver)
      self.type = vehicle_type

    def operative(self):
      pass


class Operator:

    def monitor(self):
      pass

    def send_for_repair(self, vehicle):
      pass

    def assign_vehicle(self, vehicle, driver):
      pass

    def end_shift(self, driver):
      pass
